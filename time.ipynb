# %%
import time
def countdown(t):
    while t:
        mins,secs=divmod(t,60)
        clock="{:02d}:{:02d}".format(mins,secs)
        print(clock,end="\n")
        time.sleep(1)
        t-=1

        print("fire in hole")
    t=input("enter the time")
    countdown(int(t))
